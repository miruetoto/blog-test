# %% [raw]
# ---
# title: "프랑스혁명"
# author: "최규빈"
# date: "01/02/2025"
# ---

# %% [markdown]
# ## 프랑스 혁명

# %% [markdown]
# 루이
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 혁명의 전개
#
# ### 삼부회소집

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
